# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
from dataset import MuticlassImageSegmentationDataset
import pandas as pd
from torch.utils.data import DataLoader
# torch datset splotter
from sklearn.model_selection import train_test_split
# torch metrics
import torchvision

# %%
single_masks = pd.read_csv('fashion_dataset/single_masks.csv', dtype={'image': str})

# %%
train_ds = MuticlassImageSegmentationDataset('fashion_dataset/png_images/IMAGES', 'fashion_dataset/png_masks/MASKS', single_masks, 58, 128)

# %%
img, mask, mask_one_hot = train_ds[0]

# %%
import matplotlib.pyplot as plt
plt.imshow(img.permute(1, 2, 0))
plt.show()

# %%
plt.imshow(mask.squeeze(), cmap='gray')
